# %%
#set()轉換
set('letters')#會丟棄重複的值
# Out:
# {'e', 'l', 'r', 's', 't'}

# %%
#串列轉集合 
set(['a' , 'b' , 'c' ,'d' ,'d'])#會丟棄重複的值
# Out:
# {'a', 'b', 'c', 'd'}

# %%
#tuple轉集合
set(('a' , 'b' , 'c' ,'d' ,'d'))#會丟棄重複的值
# Out:
# {'a', 'b', 'c', 'd'}

# %%
#dict轉集合,只會用到鍵
set({'apple':'red' , 'orange':'orange' ,'banana':'yellow' })
# Out:
# {'apple', 'banana', 'orange'}

# %%
# 为了避免一个页面被采集两次，链接去重是非常重要的。在代码运行时，把已发现的所有链接都放到一起，并保存在方便查询的列表里（下文示例指Python 
# 的集合set 类型）。只有“新”链接才会被采集，之后再从页面中搜索其他链接：
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                # 我们遇到了新页面
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:RS_(disambiguation)
# /wiki/Wikipedia:WikiProject_Radio_Stations
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:WPPP
# /wiki/Wikipedia:WikiProject
# /wiki/Wikipedia:Wikimedia_sister_projects
# /wiki/Help:Interwikimedia_links
# /wiki/Help:Interlanguage_links
# /wiki/List_of_ISO_639-1_codes
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Geographic_coordinate_system
# /wiki/Template:Coord
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_messages
# /wiki/MOS:TM
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:Portal/Guidelines
# /wiki/Wikipedia:Portal
# /wiki/Wikipedia:WikiProject_Portals
# /wiki/Portal:Contents/Portals
# /wiki/Portal:Contents
# /wiki/Portal:Contents/Overviews
# /wiki/Portal:Contents/Outlines
# /wiki/Portal:Contents/Lists
# /wiki/Portal:Contents/Glossaries
# /wiki/Portal:Contents/Categories
# /wiki/Portal:Contents/Indices
# /wiki/Portal:Contents/Reference
# /wiki/Portal:Contents/Culture_and_the_arts
# /wiki/Wikipedia:CFORK
# /wiki/Category:Wikipedia_content_guidelines
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Directory
# /wiki/Wikipedia:DIRECTORY
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Wikipedia_abbreviations
# /wiki/Wikipedia:Manual_of_Style/Abbreviations
# /wiki/Wikipedia:List_of_shortcuts
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Five_pillars
# /wiki/File:Encyclopedia_icon.svg
# /wiki/User:Afents/sandbox
# /wiki/User:Afents
# /wiki/Special:MyTalk
# /wiki/Case_sensitivity
# /wiki/String_(computer_science)
# /wiki/String_(disambiguation)
# /wiki/String_(structure)
# /wiki/Structure
# /wiki/Structure_(disambiguation)
# /wiki/Architectural_structure
# /wiki/File:20071123_Ratner_Center.jpg
# /wiki/Ratner_Center
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia_talk:Good_article_nominations
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_reassessment
# /wiki/Wikipedia:Good_article_nominations/Report
# /wiki/Wikipedia:Good_article_help
# /wiki/Wikipedia_talk:GAN
# /wiki/File:GA_candidate.svg
# /wiki/File:Symbol_support_vote.svg
# /wiki/Wikipedia:Criteria_for_speedy_deletion#F8
# /wiki/Help:Edit_summary
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Template:Nutshell/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/Talk:Kashmir
# /wiki/Kashmir
# /wiki/Kashmar
# /wiki/Kashmar_County
# /wiki/Counties_of_Iran
# /wiki/File:Iran_Counties.svg
# /wiki/County
# /wiki/Country
# /wiki/Country_(disambiguation)
# /wiki/Rural_area
# /wiki/Rural_(disambiguation)
# /wiki/Rural
# /wiki/File:Barossa_Valley_South_Australia.jpg
# /wiki/Australian_wine
# /wiki/File:Australian_Wine.jpg
# /wiki/Canon_(company)
# /wiki/File:Canon_wordmark.svg
# /wiki/Canon_IT_Solutions
# /wiki/List_of_legal_entity_types_by_country
# /wiki/Company_(disambiguation)
# /wiki/Company
# /wiki/And_Co
# /wiki/File:And_Co_logo.jpg
# /wiki/Color_space
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Consensus#Levels_of_consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Greek_language
# /wiki/Proto-Greek_language
# /wiki/Category:Indo-European
# /wiki/Indo-European_languages
# /wiki/Indo-European_(disambiguation)
# /wiki/Europe
# /wiki/European_Union
# /wiki/EU_(disambiguation)
# /wiki/.eu
# /wiki/File:Logo_.eu.svg
# /wiki/Special:MyContributions
# /wiki/Help:User_contributions
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Wikipedia:WikipediaSpace
# /wiki/File:WikipediaSpace-WS1-Introduction-v1.pdf
# /wiki/Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/File:Roseberry_topping_north_side.jpg
# /wiki/Roseberry_Topping
# /wiki/Summit
# /wiki/Summit_(meeting)
# /wiki/Head_of_state
# /wiki/Head_of_government
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup
# /wiki/File:Markup-logo.svg
# /wiki/User:Sara9mm1
# /wiki/Help:Getting_started
# /wiki/Wikipedia:Welcoming_committee/Welcome_to_Wikipedia
# /wiki/Wikipedia:Welcoming_committee
# /wiki/Wikipedia:WikiCup
# /wiki/File:Trophy.png
# /wiki/File:Trophy.jpg
# /wiki/2008%E2%80%9309_Cypriot_Cup_for_lower_divisions
# /wiki/Cypriot_Cup_for_lower_divisions
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Responsible_tagging
# /wiki/Wikipedia:Tags
# /wiki/Wikipedia:File_copyright_tags
# /wiki/Wikipedia:WikiProject_Spoken_Wikipedia/Uploading_guidelines
# /wiki/Wikipedia:WikiProject_Spoken_Wikipedia
# /wiki/Wikipedia:WIKISPEAK
# /wiki/Humour
# /wiki/Wikipedia:Pending_changes
# /wiki/Wikipedia:PCR
# /wiki/Wikipedia:TBAN
# /wiki/Wikipedia:Spam_blacklist
# /wiki/Wikipedia:Spam-blacklist
# /wiki/Wikipedia:Spam-blacklisting
# /wiki/MediaWiki:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-blacklist/log
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/Wikipedia:Request_directory
# /wiki/Wikipedia:Maintenance
# /wiki/Wikipedia:Task_Center
# /wiki/Wikipedia:Community_portal/Opentask
# /wiki/Wikipedia:Backlog
# /wiki/Wikipedia:Database_reports
# /wiki/Special:SpecialPages
# /wiki/Help:Special_page
# /wiki/Wikipedia:What_Wikipedia_is_not#Wikipedia_is_not_a_crystal_ball
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:Consensus
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:Administrators#Wheel_war
# /wiki/Wikipedia_administrators
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia:Administration
# /wiki/Management
# /wiki/Management_(disambiguation)
# /wiki/MGMT
# /wiki/O-6-methylguanine-DNA_methyltransferase
# /wiki/Protein_Data_Bank
# /wiki/File:Wwpdb-logo.png
# /wiki/Worldwide_Protein_Data_Bank
# /wiki/Protein_structure
# /wiki/File:Protein_structure_(full).png
# /wiki/Biomolecular_structure
# /wiki/Wikipedia:Vagueness
# /wiki/Wikipedia:Essays
# /wiki/Wikipedia:NOTESSAY
# /wiki/Wikipedia:Core_content_policies
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# /wiki/Category:Wikipedia_backlog
# /wiki/Category:Wikipedia_administration
# /wiki/Wikipedia:Categorization#Non-article_and_maintenance_categories
# /wiki/Wikipedia:HotCat
# /wiki/Wikipedia:Blocking_policy
# /wiki/Help:I_have_been_blocked
# /wiki/Wikipedia:Blocking_policy#Evasion_and_enforcement
# /wiki/Wikipedia:Appealing_a_block
# /wiki/Wikipedia:Article_alerts
# /wiki/Template:Article_Alerts_Navheader
# /wiki/Template_talk:Article_Alerts_Navheader
# /wiki/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Special:WhatLinksHere/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Talk:Atlas_Shrugged
# /wiki/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Special:WhatLinksHere/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Talk:Algeria
# /wiki/Algeria
# /wiki/Arabic_language
# /wiki/Varieties_of_Arabic
# /wiki/Classification_of_Arabic_languages
# /wiki/North_Africa
# /wiki/Regions_of_the_African_Union#North
# /wiki/List_of_regions_of_Africa
# /wiki/Regions_of_the_African_Union
# /wiki/File:Regions_of_the_African_Union.png
# /wiki/African_Union
# /wiki/File:African_Union.ogg
# /wiki/User:Dmcdevit
# /wiki/National_Archives_and_Records_Administration
# /wiki/National_Alien_Registration_Authority
# /wiki/File:State_emblem_of_Pakistan.svg
# /wiki/Special:WhatLinksHere/File:State_emblem_of_Pakistan.svg
# /wiki/Aga_Khan_III
# /wiki/File:HH_the_AGA_KHAN_1936.jpg
# /wiki/File:CC_some_rights_reserved.svg
# /wiki/Category:Wikipedia_files_on_Wikimedia_Commons
# /wiki/Category:Wikipedia_files_with_unknown_source
# /wiki/Category:Hidden_categories
# /wiki/Wikipedia:What_is_an_article%3F
# /wiki/Wikipedia:Naming_conventions_(definite_or_indefinite_article_at_beginning_of_name)
# /wiki/Category:Wikipedia_naming_conventions
# /wiki/Category:Naming_conventions
# /wiki/Help:Categories
# /wiki/Wikipedia:FAQ/Readers
# /wiki/Wikipedia:FAQ
# /wiki/Wikipedia:Contributing_to_Wikipedia
# /wiki/Wikipedia:Tips
# /wiki/Help:Menu
# /wiki/Wikipedia:Directories_and_indexes
# /wiki/Wikipedia:Indexes
# /wiki/Wikipedia:Stand-alone_list
# /wiki/Wikipedia:Manual_of_Style/Lists
# /wiki/Wikipedia:Lists
# /wiki/Help:List
# /wiki/Recipe
# /wiki/Semiconductor_fabrication
# /wiki/File:4-fach-NAND-C10.JPG
# /wiki/1.5_%C2%B5m_process
# /wiki/Semiconductor_device_fabrication
# /wiki/10_%C2%B5m_process
# /wiki/6_%C2%B5m_process
# /wiki/3_%C2%B5m_process
# /wiki/1_%C2%B5m_process
# /wiki/800_nanometer
# /wiki/Wikipedia:Citing_sources
# /wiki/Help:Footnotes
# /wiki/Help:Citation_Style_1
# /wiki/Template:Cite_journal
# /wiki/Template:Cite_journal/doc
# /wiki/Wikipedia:Subpages
# /wiki/Wikipedia:SP_(disambiguation)
# /wiki/Wikipedia:SP
# /wiki/Wikipedia:Substitution
# /wiki/Help:Substitution
# /wiki/Wikipedia:Transclusion
# /wiki/Wikipedia:Transwiki_log
# /wiki/Wikipedia:HISPAGES
# /wiki/Category:Wikipedia_project_content_guidelines
# /wiki/Wikipedia:ADMINP
# /wiki/Governance
# /wiki/Governance_(journal)
# /wiki/File:Governance_(journal).jpg
# /wiki/Wikipedia:Non-free_use_rationale_guideline
# /wiki/Wikipedia_talk:Non-free_use_rationale_guideline
# /wiki/Wikipedia:WikiProject_Fair_use
# /wiki/Wikipedia:WikiProject_Images_and_Media
# /wiki/Wikipedia:Graphics_Lab
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:GL/ILL
# /wiki/Wikipedia:GL/PHOTO
# /wiki/Wikipedia:GL/MAP
# /wiki/Wikipedia_talk:Graphics_Lab
# /wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia_talk:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:GL/M
# /wiki/Wikipedia:WikiProject_Maps/Conventions
# /wiki/Wikipedia:WikiProject_Maps
# /wiki/WikiMapia
# /wiki/Talk:Wikimapia
# /wiki/Wikimapia
# /wiki/Wikipedia:BLOGS
# /wiki/Wikipedia:VD
# /wiki/Wikipedia:Administrator_intervention_against_vandalism
# /wiki/Wikipedia:Administrator_intervention_against_vandalism/Administrator_instructions
# /wiki/Template:Uw-aiv
# /wiki/File:Information.svg
# /wiki/File:Information.png
# /wiki/File:Nuvola_apps_important.svg
# /wiki/Wikipedia:FFD
# /wiki/Wikipedia:Categories_for_discussion
# /wiki/Wikipedia:Articles_for_creation/Categories
# /wiki/Wikipedia:Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions
# /wiki/Category:Pending_AfC_submissions
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions/List
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Showcase
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Assessment
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Participants
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation/Participants
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation/Participants/Old_Requests
# /wiki/User:Nafsadh
# /wiki/File:Wikimedia_Foundation_RGB_logo_with_text.svg
# /wiki/User:Neolux
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:FUW
# /wiki/Wikipedia:Copyrights
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:WikiProject_Cooperation
# /wiki/Wikipedia:Co-op
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Village_pump_(policy)
# /wiki/Wikipedia:Village_pump_(technical)
# /wiki/Wikipedia:Village_pump_(idea_lab)
# /wiki/Wikipedia:Village_pump_(miscellaneous)
# /wiki/Wikipedia:Help_desk
# /wiki/Help:Cheatsheet
# /wiki/Wikipedia:Questions
# /wiki/Wikipedia:Reference_desk
# /wiki/Wikipedia:The_Wikipedia_Library
# /wiki/Wikipedia:WikiProject_Libraries
# /wiki/Wikipedia_talk:WikiProject_Libraries
# /wiki/Wikipedia:WikiProject_Libraries/Introduction
# /wiki/Wikipedia_talk:WikiProject_Libraries/Introduction
# /wiki/Wikipedia:WikiProject_Libraries/Members
# /wiki/Wikipedia_talk:WikiProject_Libraries/Members
# /wiki/Wikipedia:WikiProject_Libraries/Resources
# /wiki/Wikipedia_talk:WikiProject_Libraries/Resources
# /wiki/Wikipedia:WikiProject_Libraries/Assessment
# /wiki/Wikipedia_talk:WikiProject_Libraries/Assessment
# /wiki/Wikipedia:Signatures
# /wiki/Wikipedia:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30/News_and_notes
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30/In_focus
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/2019-08-30
# /wiki/Wikipedia:Wikipedia_Signpost/Archives
# /wiki/Wikipedia_talk:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Suggestions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/About
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/Years
# /wiki/Wikipedia:Wikipedia_Signpost/Subscribe
# /wiki/Wikipedia_talk:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/Next_issue
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom#Article_status
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Submissions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Coordination
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Quick_Start
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Content_guidance
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Formatting
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Formatting/Cheatsheet
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Content_guidance#How_to_contribute
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Resources
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Style
# /wiki/Wikipedia:List_of_newsletters
# /wiki/Template_talk:Newsletters
# /wiki/Wikipedia:WikiProject_Wikipedia
# /wiki/File:Wikipedia-logo-v2.svg
# /wiki/File:Commons-logo.svg
# /wiki/Public_domain
# /wiki/Intellectual_property
# /wiki/Intellectual_rights
# /wiki/Wikipedia:Verifiability#Burden_of_evidence
# /wiki/Wikipedia:VECTOR
# /wiki/Wikipedia:Skin
# /wiki/MediaWiki
# /wiki/Help:MediaWiki_namespace
# /wiki/Wikipedia:Administration#Data_structure_and_development
# /wiki/Wikipedia:Goals
# /wiki/Wikipedia:Wikipedia_is_an_encyclopedia
# /wiki/Encyclopedia
# /wiki/Encyclopedia_(disambiguation)
# /wiki/Encyclopedia_(album)
# /wiki/File:The_Drums_-_Encyclopedia.jpg
# /wiki/Template:Non-free_use_rationale#note-portion
# /wiki/Template:Non-free_use_rationale#note-resolution
# /wiki/Template:Non-free_use_rationale#note-purpose
# /wiki/Template:Non-free_use_rationale#note-replace
# /wiki/Template:Non-free_use_rationale#note-other
# /wiki/Template:Non-free_use_rationale/doc
# /wiki/Template:Non-free_use_rationale
# /wiki/Template:Non-free_use_rationale/sandbox
# /wiki/Wikipedia:Template_test_cases
# /wiki/Sandbox_(software_development)
# /wiki/Wikipedia:Sandbox
# /wiki/Wikipedia:About_the_Sandbox
# /wiki/Special:MyPage/sandbox
# /wiki/Special:WhatLinksHere/User:58.114.139.168/sandbox
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-ed45a34ecb22> in <module>()
#      17                 pages.add(newPage)
#      18                 getLinks(newPage)
# ---> 19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ...
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-5-ed45a34ecb22> in getLinks(pageUrl)
#       7 def getLinks(pageUrl):
#       8     global pages
# ----> 9     html = urlopen("http://en.wikipedia.org"+pageUrl)
#      10     bsObj = BeautifulSoup(html)
#      11     for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda3/envs/work/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
import requests
from bs4 import BeautifulSoup


def main():
    url1 = 'http://jwlin.github.io/py-scraping-analysis-book/ch1/connect.html'
    bad_url = 'http://non-existed.domain/connect.html'
    text1 = get_tag_text(url1, 'h1')
    print(text1)
    text2 = get_tag_text(url1, 'h2')
    print(text2)
    text3 = get_tag_text(bad_url, 'h1')
    print(text3)


def get_tag_text(url, tag):
    try:
        resp = requests.get(url)
        if resp.status_code == 200:
            soup = BeautifulSoup(resp.text, 'html.parser')
            return soup.find(tag).text
    except Exception as e:
        print('Exception: %s' %(e))
    return None


if __name__ == '__main__':
    main()
# Out:
# 歡迎來到 Pycone 松果城市！
# Exception: 'NoneType' object has no attribute 'text'
# None
# Exception: HTTPConnectionPool(host='non-existed.domain', port=80): Max retries exceeded with url: /connect.html (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x14ebc9208>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# None

# %%
#find
import requests
from bs4 import BeautifulSoup


def main():
    resp = requests.get('http://jwlin.github.io/py-scraping-analysis-book/ch2/blog/blog.html')
    soup = BeautifulSoup(resp.text, 'html.parser')

    # 取得第一篇 blog (h4)
    print(soup.find('h4'))
    print(soup.h4)  # 與上一行相等

    # 取得第一篇 blog 主標題
    print(soup.h4.a.text)

    # 取得所有 blog 主標題, 使用 tag
    main_titles = soup.find_all('h4')
    for title in main_titles:
        print(title.a.text)

    # 取得所有 blog 主標題, 使用 class
    # 以下寫法皆相同:
    # soup.find_all('h4', 'card-title')
    # soup.find_all('h4', {'class': 'card-title'})
    # soup.find_all('h4', class_='card-title')
    main_titles = soup.find_all('h4', 'card-title')
    for title in main_titles:
        print(title.a.text)

    # 使用 key=value 取得元件
    print(soup.find(id='mac-p'))

    # 當 key 含特殊字元時, 使用 dict 取得元件
    # print(soup.find(data-foo='mac-foo'))  # 會導致 SyntaxError
    print(soup.find('', {'data-foo': 'mac-foo'}))

    # 取得各篇 blog 的所有文字
    divs = soup.find_all('div', 'content')
    for div in divs:
        # 方法一, 使用 text (會包含許多換行符號)
        #print(div.text)
        # 方法二, 使用 tag 定位
        #print(div.h6.text.strip(), div.h4.a.text.strip(), div.p.text.strip())
        # 方法三, 使用 .stripped_strings
        print([s for s in div.stripped_strings])


if __name__ == '__main__':
    main()
# Out:
# <h4 class="card-title">
# <a href="http://www.pycone.com/blogs#pablo">Mac使用者</a>
# </h4>
# <h4 class="card-title">
# <a href="http://www.pycone.com/blogs#pablo">Mac使用者</a>
# </h4>
# Mac使用者
# Mac使用者
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# Mac使用者
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# 給初學者的 Python 網頁爬蟲與資料分析
# <p class="card-description" id="mac-p">
#                                     在Mac環境下安裝Python與Sublime Text3<a data-foo="mac-foo" href="http://www.pycone.com/blogs/mac-python-environment"> <br/>Read More </a>
# </p>
# <a data-foo="mac-foo" href="http://www.pycone.com/blogs/mac-python-environment"> <br/>Read More </a>
# ['開發環境設定', 'Mac使用者', '在Mac環境下安裝Python與Sublime Text3', 'Read More']
# ['資料科學', '給初學者的 Python 網頁爬蟲與資料分析', '(1) 前言', 'Read More']
# ['資料科學', '給初學者的 Python 網頁爬蟲與資料分析', '(2) 套件安裝與啟動網頁爬蟲', 'Read More']
# ['資料科學', '給初學者的 Python 網頁爬蟲與資料分析', '(3) 解構並擷取網頁資料', 'Read More']
# ['資料科學', '給初學者的 Python 網頁爬蟲與資料分析', '(4) 擷取資料及下載圖片', 'Read More']
# ['資料科學', '給初學者的 Python 網頁爬蟲與資料分析', '(5) 資料分析及展示', 'Read More']

# %%
import requests
from bs4 import BeautifulSoup


def main():
    #首先，一樣要先透過requests.get連到該目標網址，然後一樣丟給了BeauitfulSoup去處理!
    resp = requests.get('http://jwlin.github.io/py-scraping-analysis-book/ch2/table/table.html')
    soup = BeautifulSoup(resp.text, 'html.parser')

    # 計算課程均價
    # 取得所有課程價錢: 方法一, 使用 index
    prices = []
    #tr就跟row一樣，所以先取tr資料
    #然後就透過迴圈去把所有tr的價格資料取出，價格td在第三欄，以index來計算的話是2。
    rows = soup.find('table', 'table').tbody.find_all('tr')
    for row in rows:
        price = row.find_all('td')[2].text
        prices.append(int(price))
    print(sum(prices)/len(prices))

    # 取得所有課程價錢: 方法二, <a> 的 parent (<td>) 的 previous_sibling
    prices = []
    links = soup.find_all('a')
    for link in links:
        price = link.parent.previous_sibling.text
        #.parent(父).previous_sibling(兄) 
        prices.append(int(price))
    print(sum(prices) / len(prices))

    # 取得每一列所有欄位資訊: find_all('td') or row.children
    rows = soup.find('table', 'table').tbody.find_all('tr')
    for row in rows:
        all_tds = row.find_all('td')  # 方法一: find_all('td')
        # all_tds = [td for td in row.children]  # 方法二: 找出 row (tr) 所有的直接 (下一層) children
        # 以下執行時會報錯, 因為最後一列的 <a> 沒有 'href' 屬性
        # print(all_tds[0].text, all_tds[1].text, all_tds[2].text, all_tds[3].a['href'], all_tds[3].a.img['src'])
        # 取得 href 屬性前先檢查其是否存在
        if 'href' in all_tds[3].a.attrs:
            href = all_tds[3].a['href']
        else:
            href = None
        print(all_tds[0].text, all_tds[1].text, all_tds[2].text, href, all_tds[3].a.img['src'])

    # 取得每一列所有欄位文字資訊: stripped_strings
    rows = soup.find('table', 'table').tbody.find_all('tr')
    for row in rows:
        print([s for s in row.stripped_strings])


if __name__ == '__main__':
    main()
# Out:
# 1823.3333333333333
# 1823.3333333333333
# 初心者 - Python入門 初學者 1490 http://www.pycone.com img/python-logo.png
# Python 網頁爬蟲入門實戰 有程式基礎的初學者 1890 http://www.pycone.com img/python-logo.png
# Python 機器學習入門實戰 (預計) 有程式基礎的初學者 1890 http://www.pycone.com img/python-logo.png
# Python 資料科學入門實戰 (預計) 有程式基礎的初學者 1890 http://www.pycone.com img/python-logo.png
# Python 資料視覺化入門實戰 (預計) 有程式基礎的初學者 1890 http://www.pycone.com img/python-logo.png
# Python 網站架設入門實戰 (預計) 有程式基礎的初學者 1890 None img/python-logo.png
# ['初心者 - Python入門', '初學者', '1490']
# ['Python 網頁爬蟲入門實戰', '有程式基礎的初學者', '1890']
# ['Python 機器學習入門實戰 (預計)', '有程式基礎的初學者', '1890']
# ['Python 資料科學入門實戰 (預計)', '有程式基礎的初學者', '1890']
# ['Python 資料視覺化入門實戰 (預計)', '有程式基礎的初學者', '1890']
# ['Python 網站架設入門實戰 (預計)', '有程式基礎的初學者', '1890']

# %%
import requests
import re
from bs4 import BeautifulSoup


def main():
    resp = requests.get('http://jwlin.github.io/py-scraping-analysis-book/ch2/blog/blog.html')
    soup = BeautifulSoup(resp.text, 'html.parser')

    # 找出所有 'h' 開頭的標題文字
    titles = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    for title in titles:
        print(title.text.strip())

    # 利用 regex 找出所有 'h' 開頭的標題文字
    for title in soup.find_all(re.compile('h[1-6]')):
        print(title.text.strip())

    # 找出所有 .png 結尾的圖片
    imgs = soup.find_all('img')
    for img in imgs:
        if 'src' in img.attrs:
            if img['src'].endswith('.png'):
                print(img['src'])

    # 利用 regex 找出所有 .png 結尾的圖片
    for img in soup.find_all('img', {'src': re.compile('\.png$')}):
        print(img['src'])

    # 找出所有 .png 結尾且含 'beginner' 的圖片
    imgs = soup.find_all('img')
    for img in imgs:
        if 'src' in img.attrs:
            if 'beginner' in img['src'] and img['src'].endswith('.png'):
                print(img['src'])

    # 利用 regex 找出所有 .png 結尾且含 'beginner' 的圖片
    for img in soup.find_all('img', {'src': re.compile('beginner.*\.png$')}):
        print(img['src'])


if __name__ == '__main__':
    main()
# Out:
# Python教學文章
# 開發環境設定
# Mac使用者
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# Python教學文章
# 開發環境設定
# Mac使用者
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# static/python-for-beginners.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python-for-beginners.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python-for-beginners.png
# static/python-for-beginners.png

# %%
import requests
from bs4 import BeautifulSoup


def main():
    print('蘋果今日焦點')
    dom = requests.get('http://www.appledaily.com.tw/appledaily/hotdaily/headline').text
    soup = BeautifulSoup(dom, 'html5lib')
    for ele in soup.find('ul', 'all').find_all('li'):
        print(
            ele.find('div', 'aht_title_num').text,
            ele.find('div', 'aht_title').text
        )
    print('-----------')
    print('自由今日焦點')
    dom = requests.get('http://news.ltn.com.tw/list/newspaper').text
    soup = BeautifulSoup(dom, 'html5lib')
    for ele in soup.find('ul', 'list').find_all('li'):
        if ele.find('a', 'tit'):
            print(ele.find('a', 'tit').text.strip())


if __name__ == '__main__':
    main()
# Out:
# 蘋果今日焦點
# 01 嘻哈亂入麥當勞 搖搖5霸吃飽飽
# 02 林采緹辣露「神秘三角洲」網誇:保養好
# 03 藍救火 釋立院龍頭挽留郭台銘 國民黨否認 郭營冷回：不期待
# 04 黃大煒「願替她擋死」女友罹癌燒1億
# 05 【三菜一湯】亞洲廚神的台灣味 王凱傑私房料理大公開
# 06 類風濕性關節炎  全身都是病?!
# 07 李奧挺肚腩打排球 嫩模女友比基尼迎戰
# 08 北川景子變臉範本 眼鼻嘴霸前3吸複製人
# 09 莎莎被桃太郎拒合照 郭彥均苦為日本金盡
# 10 反送中衝擊民調 韓「隨時調整選戰政策」
# 11 家電展搶先看 福利品大出清 搶最後一波節能補助優惠
# 12 3人小工廠起家 登全球第3大
# 13 朱俐靜商演滿檔 千萬年收入袋
# 14 今天我最美
# 15 手術害癱 三總名醫遭起訴 腰椎植8鋼釘 二度動刀校正6根 檢認有過失
# 16 辣蘋果：宋楚瑜的入場券（余艾苔）
# 17 高鐵300萬失主 竟是陳明文 父忘光光沒報警  兒稱去菲國投資珍奶用
# 18 世界盃戰報 延長賽1分險勝 美國嚇到軟腳
# 19 《蘋果》直擊 劉泰英孤身吃蚵煎 獨自看電影 拄傘當拐杖 不見奢華排場
# 20 新北坪林 達人帶路 遊茶鄉 逛老街石頭處厝
# 21 喬山貿戰超車拼龍頭 布局越南迎轉單 躲過健身器材高關稅
# 22 韓國先晉級 3隊搶剩下2席
# 23 張艾嘉深Ｖ助攻《繼園臺》騎金獅 趙又廷調時差搶影帝
# 24 怒駁換瑜 藍營揚言告媒體 吳敦義：不重蹈換柱的痛苦 否認民調送國台辦
# 25 輕颱「玲玲」擾台 今明防雨彈 迴轉路徑奇特「劍魚」夭折成熱帶低壓
# 26 《天氣之子》集郵5冠 挾34.8億瞄準小金人
# 27 Gogoro在台售逾20萬台 開學購車潮 連4個月掛牌破萬台
# 28 班傑登記升格人夫 明年泰國宴客拼虎寶
# 29 梁家輝輸誠中國沒路用《深夜食堂》票房淪老5
# 30 恐怖巴士 警舉槍搜查乘客 闖校園搜捕 撲倒學生害斷牙滿口血
# -----------
# 自由今日焦點
# 22:29
#                         中職 Live》陳俊秀陽春砲炸裂！桃猿14：15兄弟
# 22:23
#                         （影音）「外貌協會第一把交椅」 個性美女這咖拎起來
# 22:23
#                         中職》連續安打紀錄又斷在7 胡金龍：連10打數安打太誇張
# 22:21
#                         籃球世界盃》「下限之後還有絕望」 中國無緣16強遭自家媒體狠批
# 22:19
#                         公車上伸鹹豬手  醉漢欺凌學生妹1小時
# 22:15
#                         防範「硬脫歐」 歐盟準備270億緊急資金
# 22:13
#                         9/4 雙贏彩、今彩539 頭獎均摃龜
# 22:13
#                         烈嶼鄉好康送！入住小金門 送限量高粱、神秘禮物
# 22:13
#                         要目擊者喊口號、不要放棄  香港女子墜樓亡
# 22:12
#                         貿易戰衝擊》中國又印鈔救經濟  地方發債近4兆人民幣
# 22:08
#                         台大醫院未取消門診加號  視醫師評估而定
# 22:06
#                         挽救銷售！ 傳蘋果明年將再推平價版iPhone
# 22:01
#                         不是冷氣！10天電費狂噴1500 網揪兇手是「這台」
# 22:00
#                         華為願公開原始碼  日媒：對中企不信任感「根深蒂固」
# 21:59
#                         高雄豪雨特報解除 北北基宜慎防大雨
# 21:58
#                         港府擬撤回修例  苗博雅：親中議員仍可能否決
# 21:57
#                         中職》羅力8局無失分 悍將退統一奪4連勝
# 21:55
#                         日職》王柏融代打吞K陷安打荒 火腿不敵羅德吞8連敗
# 21:55
#                         港特首宣布送中條例失效  梁振英唱衰台灣被打臉
# 21:54
#                         世足資格賽》隊史從未贏過約旦 台灣隊盼「天變」創奇蹟

# %%
import requests
import re
import json
from bs4 import BeautifulSoup


Y_MOVIE_URL = 'https://tw.movies.yahoo.com/movie_thisweek.html'

# 以下網址後面加上 "/id=MOVIE_ID" 即為該影片各項資訊
Y_INTRO_URL = 'https://tw.movies.yahoo.com/movieinfo_main.html'  # 詳細資訊
Y_PHOTO_URL = 'https://tw.movies.yahoo.com/movieinfo_photos.html'  # 劇照
Y_TIME_URL = 'https://tw.movies.yahoo.com/movietime_result.html'  # 時刻表


def get_web_page(url):
    resp = requests.get(url)
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text


def get_movies(dom):
    soup = BeautifulSoup(dom, 'html5lib')
    movies = []
    rows = soup.find_all('div', 'release_info_text')
    for row in rows:
        movie = dict()
        movie['expectation'] = row.find('div', 'leveltext').span.text.strip()
        movie['ch_name'] = row.find('div', 'release_movie_name').a.text.strip()
        movie['eng_name'] = row.find('div', 'release_movie_name').find('div', 'en').a.text.strip()
        movie['movie_id'] = get_movie_id(row.find('div', 'release_movie_name').a['href'])
        movie['poster_url'] = row.parent.find_previous_sibling('div', 'release_foto').a.img['src']
        movie['release_date'] = get_date(row.find('div', 'release_movie_time').text)
        movie['intro'] = row.find('div', 'release_text').text.replace(u'詳全文', '').strip()
        trailer_a = row.find_next_sibling('div', 'release_btn color_btnbox').find_all('a')[1]
        movie['trailer_url'] = trailer_a['href'] if 'href' in trailer_a.attrs.keys() else ''
        movies.append(movie)
    return movies


def get_date(date_str):
    # e.g. "上映日期：2017-03-23" -> match.group(0): "2017-03-23"
    pattern = '\d+-\d+-\d+'
    match = re.search(pattern, date_str)
    if match is None:
        return date_str
    else:
        return match.group(0)


def get_movie_id(url):
    # e.g., 'https://movies.yahoo.com.tw/movieinfo_main/%E6%AD%BB%E4%BE%8D2-deadpool-2-7820.html
    try:
        movie_id = url.split('.html')[0].split('-')[-1]
    except:
        movie_id = url
    return movie_id


def get_trailer_url(url):
    # e.g., 'https://tw.rd.yahoo.com/referurl/movie/thisweek/trailer/*https://tw.movies.yahoo.com/video/美女與野獸-最終版預告-024340912.html'
    return url.split('*')[1]


def get_complete_intro(movie_id):
    page = get_web_page(Y_INTRO_URL + '/id=' + movie_id)
    if page:
        soup = BeautifulSoup(page, 'html5lib')
        infobox = soup.find('div', 'gray_infobox_inner')
        title_span = infobox.find('span', 'title2')
        if title_span:
            print(title_span['title2'])
        else:
            print(infobox.text.strip())
    return None


if __name__ == '__main__':
    page = get_web_page(Y_MOVIE_URL)
    if page:
        movies = get_movies(page)
        for movie in movies:
            print(movie)
        with open('movie.json', 'w', encoding='utf-8') as f:
            json.dump(movies, f, indent=2, sort_keys=True, ensure_ascii=False)
# Out:
# {'expectation': '97%', 'ch_name': '牠 第二章', 'eng_name': 'It: Chapter Two', 'movie_id': '10042', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/July2019/LVZGczQjOiFsL0oX5KYg-486x720.jpg', 'release_date': '2019-09-05', 'intro': '導演安迪馬希堤再度集結了少年版與成年版的魯蛇俱樂部成員，為了小丑潘尼懷斯，他們在27年後重回故鄉德瑞鎮。預告從貝芙莉(潔西卡雀絲坦 飾)回到德瑞鎮的故居畫面開始，赫然發現小丑潘尼懷斯並沒有被消滅，牠在27年後又回來了，正如同這個小鎮的歷史，每27年邪惡力量就會再度甦醒。於是各奔東西的魯蛇們在闊別了多年之後，再度回到這個讓他們充滿夢靨的故鄉，一同勇敢面對小丑潘尼懷斯。', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E7%89%A0-%E7%AC%AC%E4%BA%8C%E7%AB%A0-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-081222992.html?movie_id=10042'}
# {'expectation': '78%', 'ch_name': '平行世界的愛情故事', 'eng_name': 'Parallel World Love Story', 'movie_id': '10096', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/August2019/S3xxJL4TmNGUKQ9jYzvj-1984x2835.JPG', 'release_date': '2019-09-06', 'intro': '★ 改編東野圭吾結合推理與愛情的超完美傑作 日本口碑熱賣突破150萬冊！\xa0\n★ 知名團體「Kis-My-Ft2」玉森裕太主演的奇特愛情作品\n★ 「小惡魔」吉岡里帆 × 「超能演員」染谷將太 引領觀眾進入驚愕的平行世界\n★ 日本國民歌姬 宇多田光真切歌曲〈值得被嫉妒的人生〉為本作主題曲\n\xa0\n究竟哪一邊才是真實世界？\n敦賀崇史（裕森裕太 飾）與三輪智彥（染古將太 飾）任職於腦部研究的高科技公司，兩人從小就是好朋友，彼此互相尊重也是良性競爭的對手。某日，智彥帶了一名女孩與崇史見面，沒想到那就是崇史從學生時期就朝思暮想的津野麻由子（吉岡里帆 飾）。\n\xa0\n某天早上，崇史醒來後發現麻由子竟成為自己的戀人，為自己做早餐。麻由子究竟是「好友的女友」還是「自己的女友」呢？這兩個截然不同的世界，徹底令崇史陷入瘋狂……', 'trailer_url': ''}
# {'expectation': '76%', 'ch_name': '插心之刀', 'eng_name': 'Knife+Heart', 'movie_id': '10106', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies