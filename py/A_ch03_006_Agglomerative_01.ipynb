# %%
#A_ch03_006_Agglomerative_01.ipynb
#Agglomerative Clustering 實作範例說明

# %%
import mglearn

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
mglearn.plots.plot_agglomerative_algorithm()

# %%
mglearn.plots.plot_agglomerative()
