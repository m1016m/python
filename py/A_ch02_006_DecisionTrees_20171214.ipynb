# %%
#A_ch02_006_DecisionTrees.ipynb
#安裝 graphviz (win10), 1. pip install graphviz, 2. conda install graphviz
#將 dot.exe 所在path 加到 system path 變數

# %%
import mglearn
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
mglearn.plots.plot_animal_tree()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#每一個在tree上的node皆呈現一個問題，或是一個終點(leaf node)

# %%
#1. 建造 Decision Trees
#1.1. 
import sklearn

# %%
tt=sklearn.datasets.make_moons()

# %%
import numpy as np

# %%
x=[tt[0][i][0] for i in range(100)]

# %%
len(x)
# Out:
# 100

# %%
x =[tt[0][i][0] for i in range(100)]
y =[tt[0][i][1] for i in range(100)]
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('test')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#mglearn.plots.plot_2d_classification()

# %%
#from mglearn.datasets import two_mooons

# %%
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=100, noise=0.25, random_state=3)

# %%
x,y=make_moons(n_samples=100, noise=0.25, random_state=3)
x1 =[x[i][0] for i in range(100)]
x2 =[x[i][1] for i in range(100)]
colors = (0,0,0)
area = np.pi*3
plt.scatter(x1, x2, s=area, c=colors, alpha=0.5)
plt.title('test')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mglearn
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x,y=make_moons(n_samples=100, noise=0.25, random_state=3)
#x1 =[x[i][0] for i in range(100)]
#x2 =[x[i][1] for i in range(100)]
#colors = (0,0,0)
#area = np.pi*3
#plt.scatter(x1, x2, s=area, c=colors, alpha=0.5)
mglearn.discrete_scatter(x[:,0],x[:,1],y)
plt.legend(["0,1"],loc=4)
plt.title('test')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#Two_moons dataset 產生說明
import mglearn
from sklearn.datasets import make_moons #sklearn 的 make_moons() function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#畫資料點, plt.scatter()
X,y=make_moons(n_samples=100, noise=0.25, random_state=3)
X1 =[X[i][0] for i in range(100)]
X2 =[X[i][1] for i in range(100)]
colors = (0,0,0)
area = np.pi*3
plt.scatter(X1, X2, s=area, c=colors, alpha=0.5)
plt.title('test')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %%
#畫two-moons 資料集 (依 y值 1,0), 以mglearn.discrete_scatter()
X,y=make_moons(n_samples=100, noise=0.25, random_state=3)
mglearn.discrete_scatter(X[:,0],X[:,1],y)
plt.legend(["0,1"],loc=4)
plt.title('two-moons')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
mglearn.plots.plot_tree_progressive()

# %%
#==============================================================================
#隨機森林(Random forests) 說明範例,以two_moons dataset

# %%
#step1. 載入scikit-learn 中 RandomForestClassifier module
#       及 make_moons module
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_moons

# %%
#step2. 以make_moons() 產生100個資料點的資料集
X,y=make_moons(n_samples=100, noise=0.25,random_state=3)

# %%
#step3. 準備訓練(train)與測試(test)資料集
#       import train_test_split() function
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,
                                              random_state=42)

# %%
#step4. 以 RandomForestClassifier() 建立一個5棵樹的隨機森林 'forest'
forest=RandomForestClassifier(n_estimators=5,random_state=2)

# %%
#step5. 以train dataset (X_train,y_train) fit model
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=1,
#             oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
#step6. 檢視 'forest' 屬性 'estimator_' (存放各棵樹的資料)
print(forest.estimators_)
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=1872583848, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=794921487, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
# ...

# %%
#step6.1 將 forest.estimator_ 值, 繪圖比較分析
fig,axes=plt.subplots(2,3,figsize=(20,10))
for i, (ax,tree) in enumerate(zip(axes.ravel(),forest.estimators_)):
    ax.set_title("Tree {}".format(i))
    mglearn.plots.plot_tree_partition(X_train,y_train,tree,ax=ax)
    
mglearn.plots.plot_2d_separator(forest,X_train, fill=True,ax=axes[-1,-1],alpha=.4)
axes[-1,-1].set_title("Random Forest")
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)

# %%
#python enumerate 說明
my_list = ['apple', 'banana', 'grapes', 'pear']
for c, value in enumerate(my_list, 1):
    print(c, value)
# Out:
# 1 apple
# 2 banana
# 3 grapes
# 4 pear

# %%
#reval() 說明, 降階
x = np.array([[1, 2, 3], [4, 5, 6]])
print(np.ravel(x))
# Out:
# [1 2 3 4 5 6]
