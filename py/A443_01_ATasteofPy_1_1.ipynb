# %%
#into/youtube.py

# %%
import json

# %%
from urllib.request import urlopen

# %%
url="http://www.iiiedu.org.tw/south/" #html file

# %%
response=urlopen(url)

# %%
contents = response.read()

# %%
text=contents.decode('utf8')

# %%
for t in text:
    print(t)
# Out:
# <
# !
# D
# O
# C
# T
# Y
# P
# E
#
# h
# t
# m
# l
#
# P
# U
# B
# L
# I
# C
#
# "
# -
# /
# /
# W
# 3
# C
# /
# /
# D
# T
# D
#
# X
# H
# T
# M
# L
#
# 1
# .
# 0
#
# T
# r
# a
# n
# s
# i
# t
# i
# o
# n
# a
# l
# /
# /
# E
# N
# "
#
# "
# h
# t
# t
# p
# :
# /
# /
# w
# w
# w
# .
# w
# 3
# .
# o
# r
# g
# /
# T
# R
# /
# x
# h
# t
# m
# l
# 1
# /
# D
# T
# D
# /
# x
# h
# t
# m
# l
# 1
# -
# t
# r
# a
# n
# s
# i
# t
# i
# o
# n
# a
# l
# .
# d
# t
# d
# "
# >
#
#
#
# <
# h
# t
# m
# l
#
# x
# m
# l
# n
# s
# =
# "
# h
# t
# t
# p
# :
# /
# /
# w
# w
# w
# .
# w
# 3
# .
# o
# r
# g
# /
# 1
# 9
# 9
# 9
# /
# x
# h
# t
# m
# l
# "
# >
#
#
#
# <
# H
# T
# M
# L
# >
# <
# H
# E
# A
# D
# >
#
#
#
# <
# T
# I
# T
# L
# E
# >
# 財
# 團
# 法
# 人
# 資
# 訊
# 工
# 業
# 策
# 進
# 會
#
# 數
# 位
# 教
# 育
# 研
# 究
# 所
#
# 南
# 區
# 教
# 育
# 訓
# 練
# 中
# 心
#
# 台
# 南
# 高
# 雄
# <
# /
# T
# I
# T
# L
# E
# >
#
#
#
# <
# m
# e
# t
# a
#
# n
# a
# m
# e
# =
# "
# g
# o
# o
# g
# l
# e
# -
# s
# i
# t
# e
# -
# v
# e
# ...
