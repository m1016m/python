# %%
import numpy as np #import numpy as np

# %%
import matplotlib.pyplot as plt #import matplotlib

# %%
# %matplotlib inline

# %%
plt.plot(np.arange(100)) #np.arange(), Return evenly spaced values within a given interval.

# %%
run p1_example1.py

# %%
#練習:

# %%
#參考解答:                                                  plt.plot([1, 2, 3, 4], [1, 4, -9, 16])

# %%
#進階練習 plot sine wave ,                                         參考解答: p1_exampl1_ex1.py
