# %%
#05_panda_90.ipynb
#311 Service Requests for 2005 (NYC Open Data)
#https://data.cityofnewyork.us/Social-Services/311-Service-Requests-for-2005/sxmw-f24h

# %%
import pandas as pd

# %%
complaints = pd.read_csv('311_Service_Requests_for_2005.csv') #以pd.read_csv() 將資料讀入為 DataFrame 'complaints'
# Out:
# E:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (7,8,9,10,11,12,13,14,17,18,20,41,42,43,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
complaints #檢視 DataFrame 'complaints'
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0              2575  10/22/2005 12:00:00 AM  10/28/2005 12:00:00 AM    DOT
# 1             10663  05/26/2005 12:00:00 AM  05/26/2005 12:00:00 AM   NYPD
# 2             34746  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 3             34748  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 4             33826  01/02/2005 12:00:00 AM  01/13/2005 12:00:00 AM    DOT
# 5             33827  01/04/2005 12:00:00 AM  01/12/2005 12:00:00 AM    TLC
# 6             33831  01/03/2005 12:00:00 AM  01/04/2005 12:00:00 AM    DOT
# 7             33836  01/03/2005 12:00:00 AM  01/05/2005 12:00:00 AM    DOT
# 8             33838  01/04/2005 12:00:00 AM  01/05/2005 12:00:00 AM    DOT
# 9             33840  01/03/2005 12:00:00 AM  01/03/2005 12:00:00 AM    DPR
# 10            33842  01/03/2005 12:00:00 AM  01/13/2005 12:00:00 AM    DOT
# ...

# %%
#Selecting columns and rows

# %%
#To select a column, you can index with the name of the column
complaints['Complaint Type']
# Out:
# 0                            Street Sign - Damaged
# 1                              Homeless Encampment
# 2                                Highway Condition
# 3                            Street Sign - Damaged
# 4                            Street Sign - Damaged
# 5                                  Taxi Compliment
# 6                               Sidewalk Condition
# 7                            Street Sign - Damaged
# 8                            Street Sign - Damaged
# 9                                 Animal in a Park
# 10                           Street Sign - Damaged
# 11                              Indoor Air Quality
# 12                              Food Establishment
# 13                         Maintenance or Facility
# 14                         Maintenance or Facility
# 15                           Street Sign - Damaged
# 16                                Street Condition
# 17                           Street Sign - Damaged
# ...

# %%
#get the first 5 rows of a dataframe
complaints[:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0        2575  10/22/2005 12:00:00 AM  10/28/2005 12:00:00 AM    DOT
# 1       10663  05/26/2005 12:00:00 AM  05/26/2005 12:00:00 AM   NYPD
# 2       34746  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 3       34748  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 4       33826  01/02/2005 12:00:00 AM  01/13/2005 12:00:00 AM    DOT
#
#                        Agency Name         Complaint Type  \
# 0     Department of Transportation  Street Sign - Damaged
# 1  New York City Police Department    Homeless Encampment
# 2     Department of Transportation      Highway Condition
# 3     Department of Transportation  Street Sign - Damaged
# 4     Department of Transportation  Street Sign - Damaged
#
#                        Descriptor Location Type Incident Zip  \
# 0  No Parking, Standing, Stopping        Street        10007
# 1                             NaN           NaN        11355
# ...

# %%
complaints.head(5) #這樣也可以
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0        2575  10/22/2005 12:00:00 AM  10/28/2005 12:00:00 AM    DOT
# 1       10663  05/26/2005 12:00:00 AM  05/26/2005 12:00:00 AM   NYPD
# 2       34746  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 3       34748  01/10/2005 12:00:00 AM  01/10/2005 12:00:00 AM    DOT
# 4       33826  01/02/2005 12:00:00 AM  01/13/2005 12:00:00 AM    DOT
#
#                        Agency Name         Complaint Type  \
# 0     Department of Transportation  Street Sign - Damaged
# 1  New York City Police Department    Homeless Encampment
# 2     Department of Transportation      Highway Condition
# 3     Department of Transportation  Street Sign - Damaged
# 4     Department of Transportation  Street Sign - Damaged
#
#                        Descriptor Location Type Incident Zip  \
# 0  No Parking, Standing, Stopping        Street        10007
# 1                             NaN           NaN        11355
# ...

# %%
#combine these to get the first 5 rows of a column
complaints['Complaint Type'][:5]
# Out:
# 0    Street Sign - Damaged
# 1      Homeless Encampment
# 2        Highway Condition
# 3    Street Sign - Damaged
# 4    Street Sign - Damaged
# Name: Complaint Type, dtype: object

# %%
complaints['Complaint Type'].head(5)
# Out:
# 0    Street Sign - Damaged
# 1      Homeless Encampment
# 2        Highway Condition
# 3    Street Sign - Damaged
# 4    Street Sign - Damaged
# Name: Complaint Type, dtype: object

# %%
#DataFrame 是『平衡』的:
complaints[:5]['Complaint Type']
# Out:
# 0    Street Sign - Damaged
# 1      Homeless Encampment
# 2        Highway Condition
# 3    Street Sign - Damaged
# 4    Street Sign - Damaged
# Name: Complaint Type, dtype: object

# %%
#Selecting multiple columns
complaints[['Complaint Type', 'Borough']]
# Out:
#                                   Complaint Type        Borough
# 0                          Street Sign - Damaged      MANHATTAN
# 1                            Homeless Encampment         QUEENS
# 2                              Highway Condition         QUEENS
# 3                          Street Sign - Damaged          BRONX
# 4                          Street Sign - Damaged       BROOKLYN
# 5                                Taxi Compliment    Unspecified
# 6                             Sidewalk Condition       BROOKLYN
# 7                          Street Sign - Damaged       BROOKLYN
# 8                          Street Sign - Damaged       BROOKLYN
# 9                               Animal in a Park      MANHATTAN
# 10                         Street Sign - Damaged  STATEN ISLAND
# 11                            Indoor Air Quality      MANHATTAN
# 12                            Food Establishment       BROOKLYN
# 13                       Maintenance or Facility       BROOKLYN
# ...

# %%
#look at the first 10 rows
complaints[['Complaint Type', 'Borough']][:10]
# Out:
#           Complaint Type      Borough
# 0  Street Sign - Damaged    MANHATTAN
# 1    Homeless Encampment       QUEENS
# 2      Highway Condition       QUEENS
# 3  Street Sign - Damaged        BRONX
# 4  Street Sign - Damaged     BROOKLYN
# 5        Taxi Compliment  Unspecified
# 6     Sidewalk Condition     BROOKLYN
# 7  Street Sign - Damaged     BROOKLYN
# 8  Street Sign - Damaged     BROOKLYN
# 9       Animal in a Park    MANHATTAN

# %%
#What's the most common complaint type,--> Series.value_counts()
complaints['Complaint Type'].value_counts()
# Out:
# HEATING                                      270264
# Street Light Condition                       135677
# GENERAL CONSTRUCTION                         113037
# PLUMBING                                     110998
# PAINT - PLASTER                               89466
# Sewer                                         87037
# Water System                                  84932
# Street Condition                              72750
# NONCONST                                      70186
# Noise - Street/Sidewalk                       57035
# Blocked Driveway                              50511
# General Construction/Plumbing                 47621
# ELECTRIC                                      42888
# Noise                                         39133
# Sanitation Condition                          36778
# Building/Use                                  33966
# Missed Collection (All Materials)             31072
# Dirty Conditions                              30105
# ...

# %%
#What's the most common complaint type, top 10
top_10_com=complaints['Complaint Type'].value_counts()[:10]

# %%
top_10_com
# Out:
# HEATING                    270264
# Street Light Condition     135677
# GENERAL CONSTRUCTION       113037
# PLUMBING                   110998
# PAINT - PLASTER             89466
# Sewer                       87037
# Water System                84932
# Street Condition            72750
# NONCONST                    70186
# Noise - Street/Sidewalk     57035
# Name: Complaint Type, dtype: int64

# %%
# %matplotlib inline

# %%
#繪圖展示
top_10_com.plot(kind='bar')
