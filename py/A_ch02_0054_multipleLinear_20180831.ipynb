# %%
#A_ch02_0054_multipleLinear_20180831.ipynb
#使用波士頓資料集預測房價

# %%
from sklearn import datasets

# %%
#載入boston datasets
boston = datasets.load_boston()

# %%
#step 0: 檢視 boston datasets
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
print(boston.data.shape)
# Out:
# (506, 13)

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(boston.DESCR)
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
#step 1: 將資料建成 DataFrame

# %%
import pandas as pd

# %%
#step 1.1: features X
X=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
X.head() #檢視前5筆, 13個特徵(解釋變數)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#step 1.2: target y
y=pd.DataFrame(boston.target,columns=["MEDV"])
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
#step 1.3: 以pd.concat() 整合 X 與 y 成一個 DataFrame "df1"
# for Exploratory Data Analysis,EDA (探索式資料分析)
df1=pd.concat([X,y],axis=1)
df1.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# 5     18.7  394.12   5.21  28.7
# 6     15.2  395.60  12.43  22.9
# 7     15.2  396.90  19.15  27.1
# 8     15.2  386.63  29.93  16.5
# 9     15.2  386.71  17.10  18.9

# %%
#step 2: 「探索式資料分析」(Exploratory Data Analysis, EDA)
#         在訓練一個機器學習模型之前，建議先做EDA,幫助我們檢測
#         1. 是否存在「離群值」(Outlier)
#         2. 資料的分布
#         3. 特徵之間的關係

# %%
#step 2.1: 我們以 pd.plotting.scatter_matrix() 繪製「散佈圖矩陣」
#          幫助我們視覺化探索資料集。
#          本例中有13個features及1個target 14x14 太複雜，我們先檢視
#          ['LSTAT','INDUS','NOX','RM','MEDV'] 4個features 及 target
#          你可以做其他探索檢視
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
EDA1=['LSTAT','INDUS','NOX','RM','MEDV']
pd.plotting.scatter_matrix(df1[EDA1], figsize=(15,15),marker='o',
                     hist_kwds={'bins':20},s=30,alpha=0.8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E919A3710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E906BA7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91983748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91B7C748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91A33668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91A336A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91CB13C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91CEA3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91FD2908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E91FF6BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E92036BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E9206EBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E920B0128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E920B70F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E92113668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E9214D668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E92184BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E921BEBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E921F3048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E9221DF98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E9225A438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E92293F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E922336D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E923005F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E923385F8>]],
#       dtype=object)

# %%
#step 2.2: 我們以 seaborn.heatmap(DataFrame) 繪製「熱度圖」(heat map)
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
import seaborn as sns
import numpy as np

# %%
cm=np.corrcoef(df1[EDA1].values.T)
#np.corrcoef(),相關係數(Correlation Coefficicent) 計算
#Return Pearson product-moment correlation coefficients.

# %%
sns.heatmap(cm, cbar=True, annot=True,
            square=True, fmt='.2f',annot_kws={'size':15},
            yticklabels=EDA1,xticklabels=EDA1)

# %%
#step 3: 訓練線性迴歸模型(LinearRegression) 
#3.a 以'RM' feature 做simple linear regression
from sklearn.linear_model import LinearRegression
Xs=df1.RM.values.reshape(-1,1)
ys=df1.MEDV.values
lsModel=LinearRegression().fit(Xs,ys)
lsModel
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#step 3: 訓練線性迴歸模型(LinearRegression)
#3.b 複變數迴歸, 以13個特徵
lModel=LinearRegression()
lModel.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#檢視model "lModel"的係數 .coef_ 及截距 .intercept_
print('lModel.coef_ -->',lModel.coef_)
# Out:
# lModel.coef_ --> [[-1.07170557e-01  4.63952195e-02  2.08602395e-02  2.68856140e+00
#   -1.77957587e+01  3.80475246e+00  7.51061703e-04 -1.47575880e+00
#    3.05655038e-01 -1.23293463e-02 -9.53463555e-01  9.39251272e-03
#   -5.25466633e-01]]

# %%
print('lModel.intercept_ -->',lModel.intercept_)
# Out:
# lModel.intercept_ --> [36.49110328]

# %%
#建一個 DataFrame "coef", 展示模型 lModel 各特徵的係數
coef=pd.DataFrame(boston.feature_names,columns=["features"])

# %%
coef["estimateCoef"]=lModel.coef_.reshape(13,)

# %%
coef
# Out:
#    features  estimateCoef
# 0      CRIM     -0.107171
# 1        ZN      0.046395
# 2     INDUS      0.020860
# 3      CHAS      2.688561
# 4       NOX    -17.795759
# 5        RM      3.804752
# 6       AGE      0.000751
# 7       DIS     -1.475759
# 8       RAD      0.305655
# 9       TAX     -0.012329
# 10  PTRATIO     -0.953464
# 11        B      0.009393
# 12    LSTAT     -0.525467

# %%
#我們可以觀察到 RM (average number of rooms per dwelling)
#是最高的係數, 表示RM與房價(target)高度相關, 所以我們以RM及y繪製散佈圖

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %%
plt.scatter(X.RM,y.values)
plt.xlabel("RM,average number of rooms per dwelling")
plt.ylabel("MEDV,House Price")
plt.title("Relationship between RM and Price")
plt.show()

# %%
#predict, 以 .predict() method 對X做預測
predicted_price=lModel.predict(X)

# %%
#檢視前五筆預測值
predicted_price[:5]
# Out:
# array([[30.00821269],
#        [25.0298606 ],
#        [30.5702317 ],
#        [28.60814055],
#        [27.94288232]])

# %%
#檢視: 用真實房價(y)對預測房價(predicted_price) 做散佈圖
plt.scatter(y.values,predicted_price)
plt.xlabel("Price")
plt.ylabel("Predicted Price")
plt.title("Price vs Predicted Price")
plt.show()

# %%
#異常值 (Outlier) 與 殘差圖 (Resdual Plots)

# %%
#訓練(Training Dataset)和測試資料集(Test Dataset)
#train_test_split() function
from sklearn.model_selection import train_test_split

# %%
XTrain,XTest,yTrain,yTest=train_test_split(X,y,random_state=42)

# %%
#以Training Dataset 訓練模型
lModel=LinearRegression().fit(XTrain,yTrain)

# %%
#用訓練好的 model 預測 Test Dataset
pred_test=lModel.predict(XTest)

# %%
#以Test Dataset 中，真實房價 yTest對預測房價pred_test 繪圖
plt.scatter(yTest.values,pred_test)
plt.xlabel("Price")
plt.ylabel("Predicted Price")
plt.title("Price vs Predicted Price")
plt.show()

# %%
#評估模型的績效 (R-squared) R2
lModel.score(XTrain,yTrain)
# Out:
# 0.748105199058599

# %%
lModel.score(XTest,yTest)
# Out:
# 0.6839557243179213

# %%
#使用 「殘差圖」(Residual Plots) 找離群值 (Outlier)
